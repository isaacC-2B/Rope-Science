# %%
pip install split-folders

# %%
import splitfolders

# %%
from google.colab import drive

# %%
input_file = '/content/drive/MyDrive/Version 1 DATASET/RESIZED'
output_file = '/content/drive/MyDrive/Version 1 DATASET/RESIZED/ResizedSplit'

# %%
splitfolders.ratio(input = input_file, output = output_file, seed = 35, ratio = (0.6, 0.2, 0.2), group_prefix=None)
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 1 files [00:01,  1.17s/ files]
# Copying files: 5 files [00:01,  5.11 files/s]
# Copying files: 11 files [00:01, 12.21 files/s]
# Copying files: 15 files [00:01, 16.57 files/s]
# Copying files: 20 files [00:01, 22.38 files/s]
# Copying files: 25 files [00:01, 25.94 files/s]
# Copying files: 29 files [00:01, 28.26 files/s]
# Copying files: 32 files [00:16, 28.26 files/s]
# Copying files: 33 files [00:26,  1.88s/ files]
# Copying files: 34 files [00:38,  2.82s/ files]
# Copying files: 39 files [00:38,  1.68s/ files]
# Copying files: 46 files [00:38,  1.07 files/s]
# Copying files: 51 files [00:38,  1.54 files/s]
# Copying files: 57 files [00:38,  2.33 files/s]
# Copying files: 63 files [00:39,  3.43 files/s]
# Copying files: 70 files [00:39,  5.18 files/s]
# Copying files: 76 files [00:39,  7.12 files/s]
# Copying files: 82 files [00:39,  9.71 files/s]
# Copying files: 88 files [00:39, 12.84 files/s]
# ...
